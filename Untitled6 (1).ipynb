# %%
import numpy as np
import pandas as pd
 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
 
# import os
import math

# %%
df1=pd.read_csv("/content/covid_19_india.csv")

# %%
df=pd.read_csv("/content/StatewiseTestingDetails.csv")

# %%
df2=pd.read_csv("/content/covid_vaccine_statewise.csv")

# %%
df
# Out:
#              Date                        State  TotalSamples Negative  Positive
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0
# ...           ...                          ...           ...      ...       ...
# 16331  2021-08-06                  West Bengal    15999961.0      NaN       NaN
# 16332  2021-08-07                  West Bengal    16045662.0      NaN       NaN
# 16333  2021-08-08                  West Bengal    16092192.0      NaN       NaN
# 16334  2021-08-09                  West Bengal    16122345.0      NaN       NaN
# 16335  2021-08-10                  West Bengal    16162814.0      NaN       NaN
#
# ...

# %%
df.Date = pd.to_datetime(df.Date, format="%Y/%m/%d")

fig = px.line(df, x='Date', y='TotalSamples', color='State', title='Total number of samples collected for Covid-19 testing(Statewise)')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pip install --upgrade plotly

# %%
fig = px.treemap(df, path=["State"], values="Positive", height = 750,
                 title="<b>Total positive Cases Breakdown by state</b>",
                 color_discrete_sequence = px.colors.qualitative.Set3)

fig.update_traces(textinfo = "label+text+value")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_1 = df1.groupby(['State/UnionTerritory'])['Cured','Deaths','Confirmed'].sum().reset_index()
df_1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#           State/UnionTerritory      Cured   Deaths  Confirmed
# 0  Andaman and Nicobar Islands    1848286    27136    1938498
# 1               Andhra Pradesh  370426530  2939367  392432753
# 2            Arunachal Pradesh    6588149    26799    7176907
# 3                        Assam   92678680   638323   99837011
# 4                        Bihar  125122902  1093466  132231166

# %%
fig = px.bar(df_1, x='State/UnionTerritory', y='Confirmed')
fig.update_traces(marker_color='darkgreen')
fig.update_layout(width=700, height=500, bargap=0.05)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df1.rename(columns={"State/UnionTerritory":"State"},inplace=True)

# %%
Deaths_Statewise= df1.groupby("State").Deaths.max().sort_values()

# %%
Deaths_Statewise.plot(kind="bar",figsize=(15,5))
plt.xlabel("States")
plt.ylabel("No.of Deaths")
# Out:
# Text(0, 0.5, 'No.of Deaths')

# %%
Cured_Statewise= df1.groupby("State").Cured.max().sort_values()

# %%
Cured_Statewise.plot(kind="bar",figsize=(15,5))
plt.xlabel("States")
plt.ylabel("No.of Cured")
# Out:
# Text(0, 0.5, 'No.of Cured')

# %%
df1["Active"] = df1.Confirmed - (df1.Cured+df1.Deaths)

# %%
Active_Statewise = df1.groupby("State").Active.max().sort_values()

# %%
Active_Statewise.plot(kind="bar",figsize=(15,5))
plt.xlabel("States")
plt.ylabel("No.of Active")
# Out:
# Text(0, 0.5, 'No.of Active')

# %%
trace = go.Pie(labels=['Cured', 'Deaths', 'Confirmed'],
               values=[df1.Cured.sum(), df1.Deaths.sum(), df1.Confirmed.sum()], 
               title="<b>country Covid19 <br> Cases</b>",
               title_font_size=18,
               hovertemplate="<b>%{label}</b><br>%{value}<br><i>%{percent}</i>",
               #hoverinfo='percent+value+label', 
               textinfo='percent',
               textposition='inside',
               hole=0.6,
               showlegend=True,
               marker=dict(colors=["#A904DE", "#FF5733", "C5A803"],
                           line=dict(color='#000000',
                                     width=2),
                          ),
               name=""
              )
fig=go.Figure(data=[trace])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
state_cases = df1.groupby('State')['Confirmed','Deaths','Cured'].max().reset_index()
state_cases['Active'] = state_cases['Confirmed'] - (state_cases['Deaths']+ state_cases['Cured'])
state_cases["Death Rate (per 100)"] = np.round(100*state_cases["Deaths"]/state_cases["Confirmed"],2)
state_cases["Cure Rate (per 100)"] = np.round(100*state_cases["Cured"]/state_cases["Confirmed"],2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
state_cases
# Out:
#                                        State  ...  Cure Rate (per 100)
# 0                Andaman and Nicobar Islands  ...                98.20
# 1                             Andhra Pradesh  ...                98.37
# 2                          Arunachal Pradesh  ...                94.50
# 3                                      Assam  ...                97.14
# 4                                      Bihar  ...                98.63
# 5                                  Bihar****  ...                97.97
# 6           Cases being reassigned to states  ...                 0.00
# 7                                 Chandigarh  ...                98.64
# 8                               Chhattisgarh  ...                98.49
# 9                     Dadra and Nagar Haveli  ...                98.88
# 10  Dadra and Nagar Haveli and Daman and Diu  ...                99.92
# 11                               Daman & Diu  ...                 0.00
# ...

# %%
df2
# Out:
#       Updated On  ... Total Individuals Vaccinated
# 0     16/01/2021  ...                      48276.0
# 1     17/01/2021  ...                      58604.0
# 2     18/01/2021  ...                      99449.0
# 3     19/01/2021  ...                     195525.0
# 4     20/01/2021  ...                     251280.0
# ...          ...  ...                          ...
# 7840  11/08/2021  ...                          NaN
# 7841  12/08/2021  ...                          NaN
# 7842  13/08/2021  ...                          NaN
# 7843  14/08/2021  ...                          NaN
# 7844  15/08/2021  ...                          NaN
#
# [7845 rows x 24 columns]

# %%
mask = (df2["State"]=="India")
x3 = df2[mask]["Updated On"]

# %%
y3 = df2[mask]["Total Individuals Vaccinated"]

# %%
fig = px.line(x = x3, y = y3,color_discrete_sequence=px.colors.qualitative.Dark2,
       title="Total Individuals Registering for vaccines")

fig.update_xaxes(title_text="Dates")
fig.update_yaxes(title_text="Number of Persons Registered")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
y1 = df2[mask]["First Dose Administered"]
y2 = df2[mask]["Second Dose Administered"]

# %%
fig = px.line(x = x3, y = [y1,y2],color_discrete_sequence=px.colors.qualitative.Dark2,
       title="First Dose and Second Dose Administered Comparison all over India")

fig.update_xaxes(title_text="Dates")
fig.update_yaxes(title_text="No of persons given vaccines")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
male = df2[mask]["Male(Individuals Vaccinated)"]
female = df2[mask]["Female(Individuals Vaccinated)"]
transgender = df2[mask]["Transgender(Individuals Vaccinated)"]

# %%
px.line(x = x3, y = [male,female,transgender],color_discrete_sequence=px.colors.qualitative.Dark2,
       title="Male vs Female vaccinated in India")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_Odisha=df2[df2['State']=='Odisha']
df_Maharashtra=df2[df2['State']=='Maharashtra']
df_Delhi=df2[df2['State']=='Delhi']

# %%
Doses = df_Odisha["Total Doses Administered"].max() 
Vaccinated = df_Odisha["Total Individuals Vaccinated"].max()  
px.pie(names=["Doses Administered","People Vaccinated"],values=[Doses,Vaccinated],title="Doses administered vs People Vaccinated")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
maxDoses = df_Maharashtra["Total Doses Administered"].max() 
Vaccinated = df_Maharashtra["Total Individuals Vaccinated"].max()  
px.pie(names=["Doses Administered","People Vaccinated"],values=[Doses,Vaccinated],title="Doses administered vs People Vaccinated")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Doses = df_Delhi["Total Doses Administered"].max() 
Vaccinated = df_Delhi["Total Individuals Vaccinated"].max()  
px.pie(names=["Doses Administered","People Vaccinated"],values=[Doses,Vaccinated],title="Doses administered vs People Vaccinated")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
